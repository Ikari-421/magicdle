# %%
from DataToolsBox import ToolsBox

url_dataframe = "all_mtg_cards.zip"
toolBox = ToolsBox(url_dataframe)

# %%
toolBox.dtx_describe()

# %%
toolBox.df.head(100)

# %%
df_legendary = toolBox.df.loc[(toolBox.df['type'].str.contains(r'Legendary (Artifact )?Creature', regex=True))]
df_legendary.loc[toolBox.df['type'].str.contains(r'Legendary Artifact Creature')].head(1)
# Out:
# C:\Users\pilep\AppData\Local\Temp\ipykernel_15712\1119088515.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df_legendary = toolBox.df.loc[(toolBox.df['type'].str.contains(r'Legendary (Artifact )?Creature', regex=True))]
#                         name  multiverse_id  layout  names     mana_cost  cmc  \
# 1580  Breya, Etherium Shaper       489865.0  normal    NaN  {W}{U}{B}{R}  4.0
#
#                     colors        color_identity  \
# 1580  ['B', 'R', 'U', 'W']  ['B', 'R', 'U', 'W']
#
#                                      type     supertypes   subtypes  rarity  \
# 1580  Legendary Artifact Creature — Human  ['Legendary']  ['Human']  Mythic
#
#                                                    text flavor         artist  \
# 1580  When Breya, Etherium Shaper enters the battlef...    NaN  Clint Cearley
#
#      number power toughness loyalty variations watermark  border  timeshifted  \
# ...

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df_col_selected = df_legendary[["name", "cmc", "colors", "type", "subtypes", "rarity", "power", "toughness", "set_name"]]
df_col_selected.describe(include="all").T
# Out:
#             count unique                                top  freq      mean  \
# name         5699   1760        Thalia, Guardian of Thraben    16       NaN
# cmc        5699.0    NaN                                NaN   NaN  4.379014
# colors       5586     33                              ['B']   584       NaN
# type         5699    548  Legendary Creature — Human Wizard   325       NaN
# subtypes     5697    540                ['Human', 'Wizard']   328       NaN
# rarity       5699      6                               Rare  3072       NaN
# power        5699     15                                  3  1370       NaN
# toughness    5699     17                                  3  1383       NaN
# set_name     5699    344                Magic Online Promos   411       NaN
#
#                 std  min  25%  50%  75%   max
# name            NaN  NaN  NaN  NaN  NaN   NaN
# cmc        1.800088  0.0  3.0  4.0  5.0  15.0
# colors          NaN  NaN  NaN  NaN  NaN   NaN
# ...

# %%
df_col_selected["colors"] = df_col_selected["colors"].fillna("['UC']")
type(df_col_selected.iloc[0]["colors"])
# Out:
# C:\Users\pilep\AppData\Local\Temp\ipykernel_15712\323942801.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_col_selected["colors"] = df_col_selected["colors"].fillna("['UC']")
# str

# %%
df_col_selected.describe(include="all").T
# Out:
#             count unique                                top  freq      mean  \
# name         5699   1760        Thalia, Guardian of Thraben    16       NaN
# cmc        5699.0    NaN                                NaN   NaN  4.379014
# colors       5699     34                              ['B']   584       NaN
# type         5699    548  Legendary Creature — Human Wizard   325       NaN
# subtypes     5697    540                ['Human', 'Wizard']   328       NaN
# rarity       5699      6                               Rare  3072       NaN
# power        5699     15                                  3  1370       NaN
# toughness    5699     17                                  3  1383       NaN
# set_name     5699    344                Magic Online Promos   411       NaN
#
#                 std  min  25%  50%  75%   max
# name            NaN  NaN  NaN  NaN  NaN   NaN
# cmc        1.800088  0.0  3.0  4.0  5.0  15.0
# colors          NaN  NaN  NaN  NaN  NaN   NaN
# ...

# %%
df_col_selected = df_col_selected.drop_duplicates(subset=["name"])

# %%
# a=input("ton nom?")
to_find = "Arcanis the Omnipotent"
given = "Zareth San, the Trickster"

details_to_find, details_given = [], []

details_to_find = df_col_selected.loc[df_col_selected["name"].str.contains(to_find)].to_dict(orient='records')
details_given = df_col_selected.loc[df_col_selected["name"].str.contains(given)].to_dict(orient='records')
details_to_find = details_to_find[0]
details_given = details_given[0]
# pd.DataFrame()

# %%
details_to_find
# Out:
# {'name': 'Arcanis the Omnipotent',
#  'cmc': 6.0,
#  'colors': "['U']",
#  'type': 'Legendary Creature — Wizard',
#  'subtypes': "['Wizard']",
#  'rarity': 'Rare',
#  'power': '3',
#  'toughness': '4',
#  'set_name': 'Tenth Edition'}

# %%
details_to_find['name']
# Out:
# 'Arcanis the Omnipotent'

# %%
details_given
# Out:
# [{'name': 'Zareth San, the Trickster',
#   'cmc': 5.0,
#   'colors': "['B', 'U']",
#   'type': 'Legendary Creature — Merfolk Rogue',
#   'subtypes': "['Merfolk', 'Rogue']",
#   'rarity': 'Rare',
#   'power': '4',
#   'toughness': '4',
#   'set_name': 'Magic Online Promos'}]

# %%
import pandas as pd
details_given_test = pd.DataFrame([details_given[0],details_to_find[0]])
details_given_test
# Out:
#                         name  cmc      colors  \
# 0  Zareth San, the Trickster  5.0  ['B', 'U']
# 1     Arcanis the Omnipotent  6.0       ['U']
#
#                                  type              subtypes rarity power  \
# 0  Legendary Creature — Merfolk Rogue  ['Merfolk', 'Rogue']   Rare     4
# 1         Legendary Creature — Wizard            ['Wizard']   Rare     3
#
#   toughness             set_name
# 0         4  Magic Online Promos
# 1         4        Tenth Edition

# %%
type(df_col_selected['colors'].loc[df_col_selected["name"].str.contains(to_find)])
# Out:
# pandas.core.series.Series

# %%
type(df_col_selected['colors'].loc[df_col_selected["name"].str.contains("Ulamog, the Infinite Gyre")])
# Out:
# pandas.core.series.Series

# %%
import pandas as pd

# Création d'un index multi-niveaux
index = pd.MultiIndex.from_tuples([('A', 1), ('A', 2), ('B', 1), ('B', 2)])

# Création d'un DataFrame avec un index multi-niveaux
data = {'valeur': [10, 20, 30, 40]}
df = pd.DataFrame(data, index=index)

print(df)
# Out:
#      valeur
# A 1      10
#   2      20
# B 1      30
#   2      40
